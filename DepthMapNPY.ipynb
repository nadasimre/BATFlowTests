# %% [markdown]
# <a href="https://colab.research.google.com/github/nadasimre/BAT_Tests/blob/main/DepthMapNPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2

depth_map_cube = np.load("0004_depth_map.npy")
depth_map_cube_normal = np.load("0001_depth_map_normalized.npy")
depth_map_gundam_normal = np.load("0002_depth_map_normalized.npy")

# %%
#for l in depth_map_cube:
#    print(*[e[0] for e in l])

# %%
#for l in depth_map_cube_normal:
#    print(*[e[0] for e in l])

# %%
#for l in depth_map_gundam_normal:
#    print(*[e[0] for e in l])

# %%
print(depth_map_cube.shape)
print(depth_map_cube_normal.shape)
print(depth_map_gundam_normal.shape)
# Out:
# (1080, 1920, 4)
# (1080, 1920, 4)
# (1080, 1920, 4)

# %%
plt.imshow(depth_map_cube)
plt.show()

# %%
plt.imshow(depth_map_cube_normal)
plt.show()

# %%
plt.imshow(depth_map_gundam_normal)
plt.show()
